# %%
import pandas as pd

#null처리함수
def fillna(df):
    df['Age'].fillna(df['Age'].mean(), inplace=True)
    df['Cabin'].fillna('N', inplace=True)
    df['Embarked'].fillna('N', inplace=True)
    df['Fare'].fillna(0, inplace=True)
    return df

#머신러닝 알고리즘에 불필요한 피처 제거
def drop_features(df):
    #방법1 df.drop(['PassengerId', 'Name', 'Ticket'], axis=1, inplace=True)
    df.drop(columns=['PassengerId', 'Name', 'Ticket'], inplace=True) #방법2
    return df

def format_features(df):
    from sklearn.preprocessing import LabelEncoder
    df['Cabin'] = df['Cabin'].str[0]
    features = ['Sex', 'Cabin', 'Embarked'] #숫자로 나타낼 핑드
    for feature in features:
        le= LabelEncoder()
        df[feature]=le.fit_transform(df[feature])
    return df

#앞에 만든 함수를 차례대로 실행
def transform_features(df):
    df = fillna(df)
    df = drop_features(df)
    df = format_features(df)
    return df

def get_clf_eval(y_test, pred):
    from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print(f'정확도:{accuracy:.4f}, 정밀도:{precision:.4f}, 재현율:{recall:.4f}')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

titanic_df = pd.read_csv('./titanic_train.csv')
y_titanic_df = titanic_df['Survived']
X_titanic_df= titanic_df.drop('Survived', axis=1)

X_titanic_df = transform_features(X_titanic_df)
X_train, X_test, y_train, y_test =  train_test_split(X_titanic_df, y_titanic_df, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr_clf = LogisticRegression(solver='liblinear')
lr_clf.fit(X_train, y_train)
pred = lr_clf.predict(X_test)
get_clf_eval(y_test, pred)
# Out:
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101

# %%
lr_clf.predict_proba(X_test)
# Out:
# array([[0.85157316, 0.14842684],
#        [0.87164641, 0.12835359],
#        [0.92390378, 0.07609622],
#        [0.08235579, 0.91764421],
#        [0.35114944, 0.64885056],
#        [0.58232192, 0.41767808],
#        [0.08988961, 0.91011039],
#        [0.07387906, 0.92612094],
#        [0.5302779 , 0.4697221 ],
#        [0.34005273, 0.65994727],
#        [0.89473077, 0.10526923],
#        [0.27896725, 0.72103275],
#        [0.86625057, 0.13374943],
#        [0.13132511, 0.86867489],
#        [0.06667393, 0.93332607],
#        [0.26974096, 0.73025904],
#        [0.84658392, 0.15341608],
#        [0.75966633, 0.24033367],
#        [0.88816843, 0.11183157],
#        [0.72057064, 0.27942936],
#        [0.69815567, 0.30184433],
#        [0.05845301, 0.94154699],
#        [0.86625664, 0.13374336],
#        [0.59788665, 0.40211335],
#        [0.31760727, 0.68239273],
#        [0.12342447, 0.87657553],
#        [0.87900237, 0.12099763],
#        [0.31950622, 0.68049378],
#        [0.1976166 , 0.8023834 ],
#        [0.41913511, 0.58086489],
#        [0.86646798, 0.13353202],
#        [0.34529389, 0.65470611],
#        [0.86489605, 0.13510395],
#        [0.57721712, 0.42278288],
#        [0.90319033, 0.09680967],
#        [0.5617435 , 0.4382565 ],
#        [0.91038386, 0.08961614],
#        [0.75805481, 0.24194519],
#        [0.73919161, 0.26080839],
#        [0.87052607, 0.12947393],
#        [0.78082253, 0.21917747],
#        [0.83707847, 0.16292153],
#        [0.8683526 , 0.1316474 ],
#        [0.93752189, 0.06247811],
#        [0.13764904, 0.86235096],
#        [0.8714842 , 0.1285158 ],
#        [0.8714842 , 0.1285158 ],
#        [0.05697712, 0.94302288],
#        [0.81165864, 0.18834136],
#        [0.77005893, 0.22994107],
#        [0.58605917, 0.41394083],
#        [0.47989346, 0.52010654],
#        [0.15698159, 0.84301841],
#        [0.83116359, 0.16883641],
#        [0.54884686, 0.45115314],
#        [0.80707588, 0.19292412],
#        [0.78846636, 0.21153364],
#        [0.56594553, 0.43405447],
#        [0.91321045, 0.08678955],
#        [0.92244657, 0.07755343],
#        [0.82445607, 0.17554393],
#        [0.40247167, 0.59752833],
#        [0.20249426, 0.79750574],
#        [0.55502037, 0.44497963],
#        [0.37356117, 0.62643883],
#        [0.87403066, 0.12596934],
#        [0.18274352, 0.81725648],
#        [0.75017611, 0.24982389],
#        [0.14763189, 0.85236811],
#        [0.08021141, 0.91978859],
#        [0.24111437, 0.75888563],
#        [0.75517552, 0.24482448],
#        [0.58130381, 0.41869619],
#        [0.87141181, 0.12858819],
#        [0.85294369, 0.14705631],
#        [0.4321159 , 0.5678841 ],
#        [0.5375705 , 0.4624295 ],
#        [0.64085706, 0.35914294],
#        [0.88582106, 0.11417894],
#        [0.73772622, 0.26227378],
#        [0.8943425 , 0.1056575 ],
#        [0.838787  , 0.161213  ],
#        [0.26213125, 0.73786875],
#        [0.81826038, 0.18173962],
#        [0.83422519, 0.16577481],
#        [0.07215792, 0.92784208],
#        [0.06668997, 0.93331003],
#        [0.61384022, 0.38615978],
#        [0.24135083, 0.75864917],
#        [0.4626559 , 0.5373441 ],
#        [0.60988619, 0.39011381],
#        [0.83116359, 0.16883641],
#        [0.66605636, 0.33394364],
#        [0.13053058, 0.86946942],
#        [0.47083352, 0.52916648],
#        [0.85536155, 0.14463845],
#        [0.2089602 , 0.7910398 ],
#        [0.94093794, 0.05906206],
#        [0.78956263, 0.21043737],
#        [0.48286524, 0.51713476],
#        [0.95548525, 0.04451475],
#        [0.89950499, 0.10049501],
#        [0.82754774, 0.17245226],
#        [0.8757013 , 0.1242987 ],
#        [0.45438386, 0.54561614],
#        [0.49222456, 0.50777544],
#        [0.21293708, 0.78706292],
#        [0.48445725, 0.51554275],
#        [0.78979645, 0.21020355],
#        [0.43334608, 0.56665392],
#        [0.92144241, 0.07855759],
#        [0.08605528, 0.91394472],
#        [0.85561739, 0.14438261],
#        [0.37125267, 0.62874733],
#        [0.63935433, 0.36064567],
#        [0.21269138, 0.78730862],
#        [0.40282309, 0.59717691],
#        [0.04364235, 0.95635765],
#        [0.90224972, 0.09775028],
#        [0.38526639, 0.61473361],
#        [0.84689927, 0.15310073],
#        [0.86590631, 0.13409369],
#        [0.83488004, 0.16511996],
#        [0.68460984, 0.31539016],
#        [0.88181915, 0.11818085],
#        [0.73688371, 0.26311629],
#        [0.85536373, 0.14463627],
#        [0.89191003, 0.10808997],
#        [0.7750246 , 0.2249754 ],
#        [0.86080621, 0.13919379],
#        [0.30311143, 0.69688857],
#        [0.83931158, 0.16068842],
#        [0.85533032, 0.14466968],
#        [0.38031835, 0.61968165],
#        [0.80912354, 0.19087646],
#        [0.83931158, 0.16068842],
#        [0.9006628 , 0.0993372 ],
#        [0.52794985, 0.47205015],
#        [0.86903044, 0.13096956],
#        [0.72748634, 0.27251366],
#        [0.75612818, 0.24387182],
#        [0.12252711, 0.87747289],
#        [0.87141181, 0.12858819],
#        [0.28533877, 0.71466123],
#        [0.20722565, 0.79277435],
#        [0.33163779, 0.66836221],
#        [0.76699722, 0.23300278],
#        [0.35256172, 0.64743828],
#        [0.0750932 , 0.9249068 ],
#        [0.87112393, 0.12887607],
#        [0.71191736, 0.28808264],
#        [0.36902925, 0.63097075],
#        [0.421954  , 0.578046  ],
#        [0.86917977, 0.13082023],
#        [0.14510817, 0.85489183],
#        [0.74690628, 0.25309372],
#        [0.4542408 , 0.5457592 ],
#        [0.89657579, 0.10342421],
#        [0.36074314, 0.63925686],
#        [0.29830586, 0.70169414],
#        [0.8714842 , 0.1285158 ],
#        [0.81562303, 0.18437697],
#        [0.22468746, 0.77531254],
#        [0.63378393, 0.36621607],
#        [0.84883686, 0.15116314],
#        [0.85169283, 0.14830717],
#        [0.92792594, 0.07207406],
#        [0.84344831, 0.15655169],
#        [0.85113843, 0.14886157],
#        [0.82212608, 0.17787392],
#        [0.92764635, 0.07235365],
#        [0.13779565, 0.86220435],
#        [0.87178699, 0.12821301],
#        [0.8683526 , 0.1316474 ],
#        [0.23814025, 0.76185975],
#        [0.87141181, 0.12858819],
#        [0.09921971, 0.90078029],
#        [0.84732851, 0.15267149],
#        [0.83107289, 0.16892711]])

# %%
from sklearn.preprocessing import Binarizer

# %%
X = [[1, -1, 2],
    [2,0,0],
    [0, 1.1, 1.2]]

binarizer = Binarizer(threshold=1.1)
print(binarizer.fit_transform(X))
#threshold(0.0:기본)를 기준으로 X가 캍거나 작으면 0/ 크면 1을 반환
# [[1. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 1.]]
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 0. 1.]]

# %%
custom_threshold=0.5
pred_proba_1 = lr_clf.predict_proba(X_test)[:,1].reshape(-1,1)#행은 전부디&2차원으로 변환
binarizer = Binarizer(threshold=custom_threshold)
custom_predict = binarizer.fit_transform(pred_proba_1)
get_clf_eval(y_test, custom_predict)
# Out:
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101

# %%
thresholds =[0.4, 0.45, 0.50, 0.55, 0.60]

def get_eval_by_threshold(y_test, pred_proba_1, thresholds):
    from sklearn.preprocessing import Binarizer
    for custom_threshold in thresholds:
        binarizer = Binarizer(threshold=custom_threshold)
        custom_predict = binarizer.fit_transform(pred_proba_1)
        print('임계값', custom_threshold)
        get_clf_eval(y_test, custom_predict)

# %%
get_eval_by_threshold(y_test, pred_proba_1, thresholds)
# Out:
# 임계값 0.4
# 오차행렬
# [[87 23]
#  [14 55]]
# 정확도:0.7933, 정밀도:0.7051, 재현율:0.7971
# 임계값 0.45
# 오차행렬
# [[91 19]
#  [18 51]]
# 정확도:0.7933, 정밀도:0.7286, 재현율:0.7391
# 임계값 0.5
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101
# 임계값 0.55
# 오차행렬
# [[98 12]
#  [23 46]]
# 정확도:0.8045, 정밀도:0.7931, 재현율:0.6667
# 임계값 0.6
# 오차행렬
# [[101   9]
#  [ 26  43]]
# 정확도:0.8045, 정밀도:0.8269, 재현율:0.6232

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np

# 레이블 값이 1일때의 예측 확률을 추출 
pred_proba_class1 = lr_clf.predict_proba(X_test)[:, 1] 

# 실제값 데이터 셋과 레이블 값이 1일 때의 예측 확률을 precision_recall_curve 인자로 입력 
precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_class1 )
print('반환된 분류 결정 임곗값 배열의 Shape:', thresholds.shape)
print('반환된 precisions 배열의 Shape:', precisions.shape)
print('반환된 recalls 배열의 Shape:', recalls.shape)

print("thresholds 5 sample:", thresholds[:5])
print("precisions 5 sample:", precisions[:5])
print("recalls 5 sample:", recalls[:5])

#반환된 임계값 배열 로우가 147건이므로 샘플로 10건만 추출하되, 임곗값을 15 Step으로 추출. 
thr_index = np.arange(0, thresholds.shape[0], 15)
print('샘플 추출을 위한 임계값 배열의 index 10개:', thr_index)
print('샘플용 10개의 임곗값: ', np.round(thresholds[thr_index], 2))

# 15 step 단위로 추출된 임계값에 따른 정밀도와 재현율 값 
print('샘플 임계값별 정밀도: ', np.round(precisions[thr_index], 3))
print('샘플 임계값별 재현율: ', np.round(recalls[thr_index], 3))

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

def precision_recall_curve_plot(y_test , pred_proba_c1):
    # threshold ndarray와 이 threshold에 따른 정밀도, 재현율 ndarray 추출. 
    precisions, recalls, thresholds = precision_recall_curve( y_test, pred_proba_c1)
    
    # X축을 threshold값으로, Y축은 정밀도, 재현율 값으로 각각 Plot 수행. 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # threshold 값 X 축의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    # x축, y축 label과 legend, 그리고 grid 설정
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()
    
    
precision_recall_curve_plot( y_test, lr_clf.predict_proba(X_test)[:, 1] )
# Out:
# 반환된 분류 결정 임곗값 배열의 Shape: (166,)
# 반환된 precisions 배열의 Shape: (167,)
# 반환된 recalls 배열의 Shape: (167,)
# thresholds 5 sample: [0.07755343 0.07855759 0.08678955 0.08961614 0.09680967]
# precisions 5 sample: [0.39884393 0.39534884 0.39766082 0.4        0.40236686]
# recalls 5 sample: [1.         0.98550725 0.98550725 0.98550725 0.98550725]
# 샘플 추출을 위한 임계값 배열의 index 10개: [  0  15  30  45  60  75  90 105 120 135 150 165]
# 샘플용 10개의 임곗값:  [0.08 0.12 0.13 0.16 0.19 0.26 0.42 0.54 0.65 0.76 0.87 0.96]
# 샘플 임계값별 정밀도:  [0.399 0.418 0.478 0.52  0.585 0.659 0.711 0.754 0.87  1.    1.    1.   ]
# 샘플 임계값별 재현율:  [1.    0.957 0.957 0.928 0.899 0.87  0.783 0.667 0.58  0.449 0.232 0.014]

# %%
from sklearn.metrics import f1_score

# %%
f1 = f1_score(y_test, pred)

# %%
f1
# Out:
# 0.725925925925926

# %%
def get_clf_eval(y_test, pred):
    from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    print('오차행렬')
    print(confusion)
    print(f'정확도:{accuracy:.4f}, 정밀도:{precision:.4f}, 재현율:{recall:.4f}, f1:{f1:.4f}')

# %%
get_clf_eval(y_test, pred)
# Out:
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101, f1:0.7259

# %%
threshold =[0.4, 0.45, 0.50, 0.55, 0.60]
pred_proba = lr_clf.predict_proba(X_test)
pred_proba[:, 1].reshape(-1,1)
get_eval_by_threshold(y_test, pred_proba[:, 1].reshape(-1,1), thresholds)
# Out:
# 임계값 0.07755343405496413
# 오차행렬
# [[  6 104]
#  [  1  68]]
# 정확도:0.4134, 정밀도:0.3953, 재현율:0.9855, f1:0.5643
# 임계값 0.07855759342425578
# 오차행렬
# [[  7 103]
#  [  1  68]]
# 정확도:0.4190, 정밀도:0.3977, 재현율:0.9855, f1:0.5667
# 임계값 0.08678955448027388
# 오차행렬
# [[  8 102]
#  [  1  68]]
# 정확도:0.4246, 정밀도:0.4000, 재현율:0.9855, f1:0.5690
# 임계값 0.08961613565768
# 오차행렬
# [[  9 101]
#  [  1  68]]
# 정확도:0.4302, 정밀도:0.4024, 재현율:0.9855, f1:0.5714
# 임계값 0.0968096746535631
# 오차행렬
# [[ 10 100]
#  [  1  68]]
# 정확도:0.4358, 정밀도:0.4048, 재현율:0.9855, f1:0.5738
# 임계값 0.09775027908873243
# 오차행렬
# [[11 99]
#  [ 1 68]]
# 정확도:0.4413, 정밀도:0.4072, 재현율:0.9855, f1:0.5763
# 임계값 0.09933719506341475
# 오차행렬
# [[12 98]
#  [ 1 68]]
# 정확도:0.4469, 정밀도:0.4096, 재현율:0.9855, f1:0.5787
# 임계값 0.10049501392293332
# 오차행렬
# [[13 97]
#  [ 1 68]]
# 정확도:0.4525, 정밀도:0.4121, 재현율:0.9855, f1:0.5812
# 임계값 0.10342421422313659
# 오차행렬
# [[13 97]
#  [ 2 67]]
# 정확도:0.4469, 정밀도:0.4085, 재현율:0.9710, f1:0.5751
# 임계값 0.10526922504066383
# 오차행렬
# [[14 96]
#  [ 2 67]]
# 정확도:0.4525, 정밀도:0.4110, 재현율:0.9710, f1:0.5776
# 임계값 0.10565750401750058
# 오차행렬
# [[15 95]
#  [ 2 67]]
# 정확도:0.4581, 정밀도:0.4136, 재현율:0.9710, f1:0.5801
# 임계값 0.10808997205192364
# 오차행렬
# [[15 95]
#  [ 3 66]]
# 정확도:0.4525, 정밀도:0.4099, 재현율:0.9565, f1:0.5739
# 임계값 0.11183157481430346
# 오차행렬
# [[16 94]
#  [ 3 66]]
# 정확도:0.4581, 정밀도:0.4125, 재현율:0.9565, f1:0.5764
# 임계값 0.11417894451012489
# 오차행렬
# [[17 93]
#  [ 3 66]]
# 정확도:0.4637, 정밀도:0.4151, 재현율:0.9565, f1:0.5789
# 임계값 0.11818085464019182
# 오차행렬
# [[18 92]
#  [ 3 66]]
# 정확도:0.4693, 정밀도:0.4177, 재현율:0.9565, f1:0.5815
# 임계값 0.12099762936377563
# 오차행렬
# [[19 91]
#  [ 3 66]]
# 정확도:0.4749, 정밀도:0.4204, 재현율:0.9565, f1:0.5841
# 임계값 0.12429870095833498
# 오차행렬
# [[20 90]
#  [ 3 66]]
# 정확도:0.4804, 정밀도:0.4231, 재현율:0.9565, f1:0.5867
# 임계값 0.12596934338448487
# 오차행렬
# [[21 89]
#  [ 3 66]]
# 정확도:0.4860, 정밀도:0.4258, 재현율:0.9565, f1:0.5893
# 임계값 0.12821300706194852
# 오차행렬
# [[22 88]
#  [ 3 66]]
# 정확도:0.4916, 정밀도:0.4286, 재현율:0.9565, f1:0.5919
# 임계값 0.12835359126795523
# 오차행렬
# [[23 87]
#  [ 3 66]]
# 정확도:0.4972, 정밀도:0.4314, 재현율:0.9565, f1:0.5946
# 임계값 0.12851580105826554
# 오차행렬
# [[26 84]
#  [ 3 66]]
# 정확도:0.5140, 정밀도:0.4400, 재현율:0.9565, f1:0.6027
# 임계값 0.1285881903779768
# 오차행렬
# [[29 81]
#  [ 3 66]]
# 정확도:0.5307, 정밀도:0.4490, 재현율:0.9565, f1:0.6111
# 임계값 0.12887607231836704
# 오차행렬
# [[30 80]
#  [ 3 66]]
# 정확도:0.5363, 정밀도:0.4521, 재현율:0.9565, f1:0.6140
# 임계값 0.12947392690312845
# 오차행렬
# [[31 79]
#  [ 3 66]]
# 정확도:0.5419, 정밀도:0.4552, 재현율:0.9565, f1:0.6168
# 임계값 0.13082023164156664
# 오차행렬
# [[32 78]
#  [ 3 66]]
# 정확도:0.5475, 정밀도:0.4583, 재현율:0.9565, f1:0.6197
# 임계값 0.13096956447445798
# 오차행렬
# [[33 77]
#  [ 3 66]]
# 정확도:0.5531, 정밀도:0.4615, 재현율:0.9565, f1:0.6226
# 임계값 0.13164739990951282
# 오차행렬
# [[35 75]
#  [ 3 66]]
# 정확도:0.5642, 정밀도:0.4681, 재현율:0.9565, f1:0.6286
# 임계값 0.1335320194009651
# 오차행렬
# [[36 74]
#  [ 3 66]]
# 정확도:0.5698, 정밀도:0.4714, 재현율:0.9565, f1:0.6316
# 임계값 0.13374335808497564
# 오차행렬
# [[37 73]
#  [ 3 66]]
# 정확도:0.5754, 정밀도:0.4748, 재현율:0.9565, f1:0.6346
# 임계값 0.13374942694295813
# 오차행렬
# [[38 72]
#  [ 3 66]]
# 정확도:0.5810, 정밀도:0.4783, 재현율:0.9565, f1:0.6377
# 임계값 0.13409369330481752
# 오차행렬
# [[39 71]
#  [ 3 66]]
# 정확도:0.5866, 정밀도:0.4818, 재현율:0.9565, f1:0.6408
# 임계값 0.1351039481427233
# 오차행렬
# [[40 70]
#  [ 3 66]]
# 정확도:0.5922, 정밀도:0.4853, 재현율:0.9565, f1:0.6439
# 임계값 0.13919379332563558
# 오차행렬
# [[41 69]
#  [ 3 66]]
# 정확도:0.5978, 정밀도:0.4889, 재현율:0.9565, f1:0.6471
# 임계값 0.14438261480824843
# 오차행렬
# [[41 69]
#  [ 4 65]]
# 정확도:0.5922, 정밀도:0.4851, 재현율:0.9420, f1:0.6404
# 임계값 0.14463627307305527
# 오차행렬
# [[42 68]
#  [ 4 65]]
# 정확도:0.5978, 정밀도:0.4887, 재현율:0.9420, f1:0.6436
# 임계값 0.14463845053155883
# 오차행렬
# [[43 67]
#  [ 4 65]]
# 정확도:0.6034, 정밀도:0.4924, 재현율:0.9420, f1:0.6468
# 임계값 0.14466967618489696
# 오차행렬
# [[44 66]
#  [ 4 65]]
# 정확도:0.6089, 정밀도:0.4962, 재현율:0.9420, f1:0.6500
# 임계값 0.14705630627860572
# 오차행렬
# [[45 65]
#  [ 4 65]]
# 정확도:0.6145, 정밀도:0.5000, 재현율:0.9420, f1:0.6533
# 임계값 0.14830716714043918
# 오차행렬
# [[46 64]
#  [ 4 65]]
# 정확도:0.6201, 정밀도:0.5039, 재현율:0.9420, f1:0.6566
# 임계값 0.14842683993221478
# 오차행렬
# [[47 63]
#  [ 4 65]]
# 정확도:0.6257, 정밀도:0.5078, 재현율:0.9420, f1:0.6599
# 임계값 0.1488615657861482
# 오차행렬
# [[48 62]
#  [ 4 65]]
# 정확도:0.6313, 정밀도:0.5118, 재현율:0.9420, f1:0.6633
# 임계값 0.15116313824666686
# 오차행렬
# [[49 61]
#  [ 4 65]]
# 정확도:0.6369, 정밀도:0.5159, 재현율:0.9420, f1:0.6667
# 임계값 0.15267148779777656
# 오차행렬
# [[50 60]
#  [ 4 65]]
# 정확도:0.6425, 정밀도:0.5200, 재현율:0.9420, f1:0.6701
# 임계값 0.15310072839204059
# 오차행렬
# [[50 60]
#  [ 5 64]]
# 정확도:0.6369, 정밀도:0.5161, 재현율:0.9275, f1:0.6632
# 임계값 0.15341608234572096
# 오차행렬
# [[51 59]
#  [ 5 64]]
# 정확도:0.6425, 정밀도:0.5203, 재현율:0.9275, f1:0.6667
# 임계값 0.15655168739554898
# 오차행렬
# [[52 58]
#  [ 5 64]]
# 정확도:0.6480, 정밀도:0.5246, 재현율:0.9275, f1:0.6702
# 임계값 0.16068841542371026
# 오차행렬
# [[54 56]
#  [ 5 64]]
# 정확도:0.6592, 정밀도:0.5333, 재현율:0.9275, f1:0.6772
# 임계값 0.16121300394897795
# 오차행렬
# [[54 56]
#  [ 6 63]]
# 정확도:0.6536, 정밀도:0.5294, 재현율:0.9130, f1:0.6702
# 임계값 0.1629215330739266
# 오차행렬
# [[55 55]
#  [ 6 63]]
# 정확도:0.6592, 정밀도:0.5339, 재현율:0.9130, f1:0.6738
# 임계값 0.16511996175698693
# 오차행렬
# [[56 54]
#  [ 6 63]]
# 정확도:0.6648, 정밀도:0.5385, 재현율:0.9130, f1:0.6774
# 임계값 0.16577480869500402
# 오차행렬
# [[57 53]
#  [ 6 63]]
# 정확도:0.6704, 정밀도:0.5431, 재현율:0.9130, f1:0.6811
# 임계값 0.1688364133270135
# 오차행렬
# [[59 51]
#  [ 6 63]]
# 정확도:0.6816, 정밀도:0.5526, 재현율:0.9130, f1:0.6885
# 임계값 0.16892711175478553
# 오차행렬
# [[60 50]
#  [ 6 63]]
# 정확도:0.6872, 정밀도:0.5575, 재현율:0.9130, f1:0.6923
# 임계값 0.1724522559620773
# 오차행렬
# [[61 49]
#  [ 6 63]]
# 정확도:0.6927, 정밀도:0.5625, 재현율:0.9130, f1:0.6961
# 임계값 0.17554393050504621
# 오차행렬
# [[62 48]
#  [ 6 63]]
# 정확도:0.6983, 정밀도:0.5676, 재현율:0.9130, f1:0.7000
# 임계값 0.17787391606716402
# 오차행렬
# [[63 47]
#  [ 6 63]]
# 정확도:0.7039, 정밀도:0.5727, 재현율:0.9130, f1:0.7039
# 임계값 0.18173962224172538
# 오차행렬
# [[64 46]
#  [ 6 63]]
# 정확도:0.7095, 정밀도:0.5780, 재현율:0.9130, f1:0.7079
# 임계값 0.18437696876540158
# 오차행렬
# [[64 46]
#  [ 7 62]]
# 정확도:0.7039, 정밀도:0.5741, 재현율:0.8986, f1:0.7006
# 임계값 0.1883413630243203
# 오차행렬
# [[65 45]
#  [ 7 62]]
# 정확도:0.7095, 정밀도:0.5794, 재현율:0.8986, f1:0.7045
# 임계값 0.19087646051456927
# 오차행렬
# [[66 44]
#  [ 7 62]]
# 정확도:0.7151, 정밀도:0.5849, 재현율:0.8986, f1:0.7086
# 임계값 0.1929241155067911
# 오차행렬
# [[67 43]
#  [ 7 62]]
# 정확도:0.7207, 정밀도:0.5905, 재현율:0.8986, f1:0.7126
# 임계값 0.21020354837107438
# 오차행렬
# [[68 42]
#  [ 7 62]]
# 정확도:0.7263, 정밀도:0.5962, 재현율:0.8986, f1:0.7168
# 임계값 0.21043736984439287
# 오차행렬
# [[69 41]
#  [ 7 62]]
# 정확도:0.7318, 정밀도:0.6019, 재현율:0.8986, f1:0.7209
# 임계값 0.21153363611941406
# 오차행렬
# [[70 40]
#  [ 7 62]]
# 정확도:0.7374, 정밀도:0.6078, 재현율:0.8986, f1:0.7251
# 임계값 0.21917746666862198
# 오차행렬
# [[70 40]
#  [ 8 61]]
# 정확도:0.7318, 정밀도:0.6040, 재현율:0.8841, f1:0.7176
# 임계값 0.2249754017365005
# 오차행렬
# [[71 39]
#  [ 8 61]]
# 정확도:0.7374, 정밀도:0.6100, 재현율:0.8841, f1:0.7219
# 임계값 0.22994106844011059
# 오차행렬
# [[72 38]
#  [ 8 61]]
# 정확도:0.7430, 정밀도:0.6162, 재현율:0.8841, f1:0.7262
# 임계값 0.23300277713311343
# 오차행렬
# [[73 37]
#  [ 8 61]]
# 정확도:0.7486, 정밀도:0.6224, 재현율:0.8841, f1:0.7305
# 임계값 0.24033367064542333
# 오차행렬
# [[74 36]
#  [ 8 61]]
# 정확도:0.7542, 정밀도:0.6289, 재현율:0.8841, f1:0.7349
# 임계값 0.24194518713928478
# 오차행렬
# [[75 35]
#  [ 8 61]]
# 정확도:0.7598, 정밀도:0.6354, 재현율:0.8841, f1:0.7394
# 임계값 0.24387182080140668
# 오차행렬
# [[76 34]
#  [ 8 61]]
# 정확도:0.7654, 정밀도:0.6421, 재현율:0.8841, f1:0.7439
# 임계값 0.24482447846648464
# 오차행렬
# [[76 34]
#  [ 9 60]]
# 정확도:0.7598, 정밀도:0.6383, 재현율:0.8696, f1:0.7362
# 임계값 0.24982388777930198
# 오차행렬
# [[77 33]
#  [ 9 60]]
# 정확도:0.7654, 정밀도:0.6452, 재현율:0.8696, f1:0.7407
# 임계값 0.2530937248768639
# 오차행렬
# [[78 32]
#  [ 9 60]]
# 정확도:0.7709, 정밀도:0.6522, 재현율:0.8696, f1:0.7453
# 임계값 0.26080839224355323
# 오차행렬
# [[79 31]
#  [ 9 60]]
# 정확도:0.7765, 정밀도:0.6593, 재현율:0.8696, f1:0.7500
# 임계값 0.26227377805312124
# 오차행렬
# [[80 30]
#  [ 9 60]]
# 정확도:0.7821, 정밀도:0.6667, 재현율:0.8696, f1:0.7547
# 임계값 0.2631162914039619
# 오차행렬
# [[81 29]
#  [ 9 60]]
# 정확도:0.7877, 정밀도:0.6742, 재현율:0.8696, f1:0.7595
# 임계값 0.27251365642053094
# 오차행렬
# [[82 28]
#  [ 9 60]]
# 정확도:0.7933, 정밀도:0.6818, 재현율:0.8696, f1:0.7643
# 임계값 0.27942936009675073
# 오차행렬
# [[82 28]
#  [10 59]]
# 정확도:0.7877, 정밀도:0.6782, 재현율:0.8551, f1:0.7564
# 임계값 0.28808263571200654
# 오차행렬
# [[83 27]
#  [10 59]]
# 정확도:0.7933, 정밀도:0.6860, 재현율:0.8551, f1:0.7613
# 임계값 0.30184433475914313
# 오차행렬
# [[84 26]
#  [10 59]]
# 정확도:0.7989, 정밀도:0.6941, 재현율:0.8551, f1:0.7662
# 임계값 0.3153901609220423
# 오차행렬
# [[85 25]
#  [10 59]]
# 정확도:0.8045, 정밀도:0.7024, 재현율:0.8551, f1:0.7712
# 임계값 0.3339436415068391
# 오차행렬
# [[85 25]
#  [11 58]]
# 정확도:0.7989, 정밀도:0.6988, 재현율:0.8406, f1:0.7632
# 임계값 0.35914293743209047
# 오차행렬
# [[86 24]
#  [11 58]]
# 정확도:0.8045, 정밀도:0.7073, 재현율:0.8406, f1:0.7682
# 임계값 0.36064566507820667
# 오차행렬
# [[86 24]
#  [12 57]]
# 정확도:0.7989, 정밀도:0.7037, 재현율:0.8261, f1:0.7600
# 임계값 0.3662160695772038
# 오차행렬
# [[86 24]
#  [13 56]]
# 정확도:0.7933, 정밀도:0.7000, 재현율:0.8116, f1:0.7517
# 임계값 0.3861597790117322
# 오차행렬
# [[86 24]
#  [14 55]]
# 정확도:0.7877, 정밀도:0.6962, 재현율:0.7971, f1:0.7432
# 임계값 0.3901138092281581
# 오차행렬
# [[87 23]
#  [14 55]]
# 정확도:0.7933, 정밀도:0.7051, 재현율:0.7971, f1:0.7483
# 임계값 0.4021133486285055
# 오차행렬
# [[88 22]
#  [14 55]]
# 정확도:0.7989, 정밀도:0.7143, 재현율:0.7971, f1:0.7534
# 임계값 0.4139408326862144
# 오차행렬
# [[88 22]
#  [15 54]]
# 정확도:0.7933, 정밀도:0.7105, 재현율:0.7826, f1:0.7448
# 임계값 0.4176780792236942
# 오차행렬
# [[88 22]
#  [16 53]]
# 정확도:0.7877, 정밀도:0.7067, 재현율:0.7681, f1:0.7361
# 임계값 0.41869618927772195
# 오차행렬
# [[89 21]
#  [16 53]]
# 정확도:0.7933, 정밀도:0.7162, 재현율:0.7681, f1:0.7413
# 임계값 0.4227828763356339
# 오차행렬
# [[89 21]
#  [17 52]]
# 정확도:0.7877, 정밀도:0.7123, 재현율:0.7536, f1:0.7324
# 임계값 0.4340544673076553
# 오차행렬
# [[90 20]
#  [17 52]]
# 정확도:0.7933, 정밀도:0.7222, 재현율:0.7536, f1:0.7376
# 임계값 0.4382565023277317
# 오차행렬
# [[90 20]
#  [18 51]]
# 정확도:0.7877, 정밀도:0.7183, 재현율:0.7391, f1:0.7286
# 임계값 0.44497962643635713
# 오차행렬
# [[91 19]
#  [18 51]]
# 정확도:0.7933, 정밀도:0.7286, 재현율:0.7391, f1:0.7338
# 임계값 0.45115313535182827
# 오차행렬
# [[91 19]
#  [19 50]]
# 정확도:0.7877, 정밀도:0.7246, 재현율:0.7246, f1:0.7246
# 임계값 0.4624295026572786
# 오차행렬
# [[92 18]
#  [19 50]]
# 정확도:0.7933, 정밀도:0.7353, 재현율:0.7246, f1:0.7299
# 임계값 0.4697221019386013
# 오차행렬
# [[92 18]
#  [20 49]]
# 정확도:0.7877, 정밀도:0.7313, 재현율:0.7101, f1:0.7206
# 임계값 0.47205015321526134
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101, f1:0.7259
# 임계값 0.5077754358205214
# 오차행렬
# [[93 17]
#  [21 48]]
# 정확도:0.7877, 정밀도:0.7385, 재현율:0.6957, f1:0.7164
# 임계값 0.5155427508436389
# 오차행렬
# [[94 16]
#  [21 48]]
# 정확도:0.7933, 정밀도:0.7500, 재현율:0.6957, f1:0.7218
# 임계값 0.517134764472061
# 오차행렬
# [[94 16]
#  [22 47]]
# 정확도:0.7877, 정밀도:0.7460, 재현율:0.6812, f1:0.7121
# 임계값 0.5201065418463842
# 오차행렬
# [[94 16]
#  [23 46]]
# 정확도:0.7821, 정밀도:0.7419, 재현율:0.6667, f1:0.7023
# 임계값 0.5291664842755277
# 오차행렬
# [[95 15]
#  [23 46]]
# 정확도:0.7877, 정밀도:0.7541, 재현율:0.6667, f1:0.7077
# 임계값 0.5373441013570693
# 오차행렬
# [[96 14]
#  [23 46]]
# 정확도:0.7933, 정밀도:0.7667, 재현율:0.6667, f1:0.7132
# 임계값 0.5456161393262418
# 오차행렬
# [[97 13]
#  [23 46]]
# 정확도:0.7989, 정밀도:0.7797, 재현율:0.6667, f1:0.7188
# 임계값 0.5457592031070628
# 오차행렬
# [[98 12]
#  [23 46]]
# 정확도:0.8045, 정밀도:0.7931, 재현율:0.6667, f1:0.7244
# 임계값 0.5666539228066019
# 오차행렬
# [[98 12]
#  [24 45]]
# 정확도:0.7989, 정밀도:0.7895, 재현율:0.6522, f1:0.7143
# 임계값 0.5678841002653584
# 오차행렬
# [[98 12]
#  [25 44]]
# 정확도:0.7933, 정밀도:0.7857, 재현율:0.6377, f1:0.7040
# 임계값 0.578045995314535
# 오차행렬
# [[99 11]
#  [25 44]]
# 정확도:0.7989, 정밀도:0.8000, 재현율:0.6377, f1:0.7097
# 임계값 0.5808648871888102
# 오차행렬
# [[100  10]
#  [ 25  44]]
# 정확도:0.8045, 정밀도:0.8148, 재현율:0.6377, f1:0.7154
# 임계값 0.5971769068468272
# 오차행렬
# [[100  10]
#  [ 26  43]]
# 정확도:0.7989, 정밀도:0.8113, 재현율:0.6232, f1:0.7049
# 임계값 0.5975283322820649
# 오차행렬
# [[101   9]
#  [ 26  43]]
# 정확도:0.8045, 정밀도:0.8269, 재현율:0.6232, f1:0.7107
# 임계값 0.6147336117791441
# 오차행렬
# [[101   9]
#  [ 27  42]]
# 정확도:0.7989, 정밀도:0.8235, 재현율:0.6087, f1:0.7000
# 임계값 0.619681654054361
# 오차행렬
# [[102   8]
#  [ 27  42]]
# 정확도:0.8045, 정밀도:0.8400, 재현율:0.6087, f1:0.7059
# 임계값 0.6264388312010188
# 오차행렬
# [[102   8]
#  [ 28  41]]
# 정확도:0.7989, 정밀도:0.8367, 재현율:0.5942, f1:0.6949
# 임계값 0.6287473302083499
# 오차행렬
# [[103   7]
#  [ 28  41]]
# 정확도:0.8045, 정밀도:0.8542, 재현율:0.5942, f1:0.7009
# 임계값 0.6309707544790497
# 오차행렬
# [[103   7]
#  [ 29  40]]
# 정확도:0.7989, 정밀도:0.8511, 재현율:0.5797, f1:0.6897
# 임계값 0.6392568622439936
# 오차행렬
# [[104   6]
#  [ 29  40]]
# 정확도:0.8045, 정밀도:0.8696, 재현율:0.5797, f1:0.6957
# 임계값 0.6474382778128375
# 오차행렬
# [[104   6]
#  [ 30  39]]
# 정확도:0.7989, 정밀도:0.8667, 재현율:0.5652, f1:0.6842
# 임계값 0.6488505563922469
# 오차행렬
# [[104   6]
#  [ 31  38]]
# 정확도:0.7933, 정밀도:0.8636, 재현율:0.5507, f1:0.6726
# 임계값 0.654706108762655
# 오차행렬
# [[104   6]
#  [ 32  37]]
# 정확도:0.7877, 정밀도:0.8605, 재현율:0.5362, f1:0.6607
# 임계값 0.6599472655006867
# 오차행렬
# [[104   6]
#  [ 33  36]]
# 정확도:0.7821, 정밀도:0.8571, 재현율:0.5217, f1:0.6486
# 임계값 0.6683622135743061
# 오차행렬
# [[105   5]
#  [ 33  36]]
# 정확도:0.7877, 정밀도:0.8780, 재현율:0.5217, f1:0.6545
# 임계값 0.6804937846002012
# 오차행렬
# [[105   5]
#  [ 34  35]]
# 정확도:0.7821, 정밀도:0.8750, 재현율:0.5072, f1:0.6422
# 임계값 0.6823927272492543
# 오차행렬
# [[106   4]
#  [ 34  35]]
# 정확도:0.7877, 정밀도:0.8974, 재현율:0.5072, f1:0.6481
# 임계값 0.6968885698236178
# 오차행렬
# [[107   3]
#  [ 34  35]]
# 정확도:0.7933, 정밀도:0.9211, 재현율:0.5072, f1:0.6542
# 임계값 0.7016941364341214
# 오차행렬
# [[107   3]
#  [ 35  34]]
# 정확도:0.7877, 정밀도:0.9189, 재현율:0.4928, f1:0.6415
# 임계값 0.7146612297067788
# 오차행렬
# [[108   2]
#  [ 35  34]]
# 정확도:0.7933, 정밀도:0.9444, 재현율:0.4928, f1:0.6476
# 임계값 0.721032751984431
# 오차행렬
# [[108   2]
#  [ 36  33]]
# 정확도:0.7877, 정밀도:0.9429, 재현율:0.4783, f1:0.6346
# 임계값 0.7302590449062658
# 오차행렬
# [[109   1]
#  [ 36  33]]
# 정확도:0.7933, 정밀도:0.9706, 재현율:0.4783, f1:0.6408
# 임계값 0.7378687523251848
# 오차행렬
# [[110   0]
#  [ 36  33]]
# 정확도:0.7989, 정밀도:1.0000, 재현율:0.4783, f1:0.6471
# 임계값 0.7586491652729183
# 오차행렬
# [[110   0]
#  [ 37  32]]
# 정확도:0.7933, 정밀도:1.0000, 재현율:0.4638, f1:0.6337
# 임계값 0.7588856303209662
# 오차행렬
# [[110   0]
#  [ 38  31]]
# 정확도:0.7877, 정밀도:1.0000, 재현율:0.4493, f1:0.6200
# 임계값 0.7618597543721158
# 오차행렬
# [[110   0]
#  [ 39  30]]
# 정확도:0.7821, 정밀도:1.0000, 재현율:0.4348, f1:0.6061
# 임계값 0.7753125367121806
# 오차행렬
# [[110   0]
#  [ 40  29]]
# 정확도:0.7765, 정밀도:1.0000, 재현율:0.4203, f1:0.5918
# 임계값 0.7870629160238
# 오차행렬
# [[110   0]
#  [ 41  28]]
# 정확도:0.7709, 정밀도:1.0000, 재현율:0.4058, f1:0.5773
# 임계값 0.7873086220083723
# 오차행렬
# [[110   0]
#  [ 42  27]]
# 정확도:0.7654, 정밀도:1.0000, 재현율:0.3913, f1:0.5625
# 임계값 0.7910397990020411
# 오차행렬
# [[110   0]
#  [ 43  26]]
# 정확도:0.7598, 정밀도:1.0000, 재현율:0.3768, f1:0.5474
# 임계값 0.7927743536715658
# 오차행렬
# [[110   0]
#  [ 44  25]]
# 정확도:0.7542, 정밀도:1.0000, 재현율:0.3623, f1:0.5319
# 임계값 0.7975057382244707
# 오차행렬
# [[110   0]
#  [ 45  24]]
# 정확도:0.7486, 정밀도:1.0000, 재현율:0.3478, f1:0.5161
# 임계값 0.8023833955347485
# 오차행렬
# [[110   0]
#  [ 46  23]]
# 정확도:0.7430, 정밀도:1.0000, 재현율:0.3333, f1:0.5000
# 임계값 0.8172564834657172
# 오차행렬
# [[110   0]
#  [ 47  22]]
# 정확도:0.7374, 정밀도:1.0000, 재현율:0.3188, f1:0.4835
# 임계값 0.8430184133585138
# 오차행렬
# [[110   0]
#  [ 48  21]]
# 정확도:0.7318, 정밀도:1.0000, 재현율:0.3043, f1:0.4667
# 임계값 0.8523681122353222
# 오차행렬
# [[110   0]
#  [ 49  20]]
# 정확도:0.7263, 정밀도:1.0000, 재현율:0.2899, f1:0.4494
# 임계값 0.8548918260790591
# 오차행렬
# [[110   0]
#  [ 50  19]]
# 정확도:0.7207, 정밀도:1.0000, 재현율:0.2754, f1:0.4318
# 임계값 0.8622043545789946
# 오차행렬
# [[110   0]
#  [ 51  18]]
# 정확도:0.7151, 정밀도:1.0000, 재현율:0.2609, f1:0.4138
# 임계값 0.8623509637677201
# 오차행렬
# [[110   0]
#  [ 52  17]]
# 정확도:0.7095, 정밀도:1.0000, 재현율:0.2464, f1:0.3953
# 임계값 0.8686748873256527
# 오차행렬
# [[110   0]
#  [ 53  16]]
# 정확도:0.7039, 정밀도:1.0000, 재현율:0.2319, f1:0.3765
# 임계값 0.8694694160377715
# 오차행렬
# [[110   0]
#  [ 54  15]]
# 정확도:0.6983, 정밀도:1.0000, 재현율:0.2174, f1:0.3571
# 임계값 0.876575532491122
# 오차행렬
# [[110   0]
#  [ 55  14]]
# 정확도:0.6927, 정밀도:1.0000, 재현율:0.2029, f1:0.3373
# 임계값 0.8774728925968823
# 오차행렬
# [[110   0]
#  [ 56  13]]
# 정확도:0.6872, 정밀도:1.0000, 재현율:0.1884, f1:0.3171
# 임계값 0.9007802901683754
# 오차행렬
# [[110   0]
#  [ 57  12]]
# 정확도:0.6816, 정밀도:1.0000, 재현율:0.1739, f1:0.2963
# 임계값 0.9101103890139648
# 오차행렬
# [[110   0]
#  [ 58  11]]
# 정확도:0.6760, 정밀도:1.0000, 재현율:0.1594, f1:0.2750
# 임계값 0.9139447171274449
# 오차행렬
# [[110   0]
#  [ 59  10]]
# 정확도:0.6704, 정밀도:1.0000, 재현율:0.1449, f1:0.2532
# 임계값 0.9176442071473139
# 오차행렬
# [[110   0]
#  [ 60   9]]
# 정확도:0.6648, 정밀도:1.0000, 재현율:0.1304, f1:0.2308
# 임계값 0.919788592069674
# 오차행렬
# [[110   0]
#  [ 61   8]]
# 정확도:0.6592, 정밀도:1.0000, 재현율:0.1159, f1:0.2078
# 임계값 0.9249068009879902
# 오차행렬
# [[110   0]
#  [ 62   7]]
# 정확도:0.6536, 정밀도:1.0000, 재현율:0.1014, f1:0.1842
# 임계값 0.9261209430263054
# 오차행렬
# [[110   0]
#  [ 63   6]]
# 정확도:0.6480, 정밀도:1.0000, 재현율:0.0870, f1:0.1600
# 임계값 0.9278420828407675
# 오차행렬
# [[110   0]
#  [ 64   5]]
# 정확도:0.6425, 정밀도:1.0000, 재현율:0.0725, f1:0.1351
# 임계값 0.9333100272266477
# 오차행렬
# [[110   0]
#  [ 65   4]]
# 정확도:0.6369, 정밀도:1.0000, 재현율:0.0580, f1:0.1096
# 임계값 0.9333260682591462
# 오차행렬
# [[110   0]
#  [ 66   3]]
# 정확도:0.6313, 정밀도:1.0000, 재현율:0.0435, f1:0.0833
# 임계값 0.9415469883610258
# 오차행렬
# [[110   0]
#  [ 67   2]]
# 정확도:0.6257, 정밀도:1.0000, 재현율:0.0290, f1:0.0563
# 임계값 0.9430228778904556
# 오차행렬
# [[110   0]
#  [ 68   1]]
# 정확도:0.6201, 정밀도:1.0000, 재현율:0.0145, f1:0.0286
# 임계값 0.9563576524050725
# 오차행렬
# [[110   0]
#  [ 69   0]]
# 정확도:0.6145, 정밀도:0.0000, 재현율:0.0000, f1:0.0000
# C:\Users\user.DESKTOP-N8383DL\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import roc_curve
pred_proba_class1 = lr_clf.predict_proba(X_test)[:,1]

fprs, tprs, thresholds = roc_curve(y_test, pred_proba_class1)

# %%
thr_index = np.arange(1, thresholds.shape[0], 5)
thr_index
# Out:
# array([  1,   6,  11,  16,  21,  26,  31,  36,  41,  46,  51,  56,  61,
#         66,  71,  76,  81,  86,  91,  96, 101, 106, 111, 116, 121, 126,
#        131, 136, 141, 146, 151, 156, 161])

# %%
np.round(thresholds[thr_index], 2)
# Out:
# array([0.08, 0.1 , 0.11, 0.12, 0.13, 0.13, 0.14, 0.14, 0.15, 0.16, 0.17,
#        0.18, 0.21, 0.23, 0.24, 0.26, 0.32, 0.39, 0.42, 0.45, 0.52, 0.55,
#        0.58, 0.63, 0.65, 0.68, 0.73, 0.78, 0.8 , 0.85, 0.88, 0.92, 0.93])

# %%
thresholds.shape[0]
# Out:
# 166

# %%
def roc_curve_plot(y_test, pred_proba_c1):
    fprs, tprs, thresholds = roc_curve(y_test, pred_proba_c1)
    plt.plot(fprs, tprs, label='ROC')
    plt.plot([0,1], [0,1], 'k--', label='Random')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.xlabel('FPr(1 - Sensitivity)')
    plt.ylabel('TPR(Recall)')
    plt.legend()

# %%
roc_curve_plot(y_test, pred_proba[:, 1])

# %%
from sklearn.metrics import roc_auc_score

# %%
pred_proba = lr_clf.predict_proba(X_test)[:, 1]
roc_score = roc_auc_score(y_test, pred_proba)
print(f'ROC AUC값 : {roc_score:0.4f}')
# Out:
# ROC AUC값 : 0.8697

# %%
def get_clf_eval(y_test, pred, pred_proba):
    from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    roc_auc = roc_auc_score(y_test, pred_proba)
    
    print('오차행렬')
    print(confusion)
    print(f'정확도:{accuracy:.4f}, 정밀도:{precision:.4f}, 재현율:{recall:.4f}, f1:{f1:.4f}, AUC: {roc_auc:.4f}')

# %%
get_clf_eval(y_test, pred, pred_proba_class1)
# Out:
# 오차행렬
# [[93 17]
#  [20 49]]
# 정확도:0.7933, 정밀도:0.7424, 재현율:0.7101, f1:0.7259, AUC: 0.8697
